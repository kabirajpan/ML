# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='+', color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size= 0.9)

# %%
X_test
# Out:
#     age
# 18   19
# 2    47
# 21   26

# %%
X_train
# Out:
#     age
# 1    25
# 0    22
# 6    55
# 15   55
# 17   58
# 8    62
# 25   54
# 20   21
# 16   25
# 13   29
# 9    61
# 5    56
# 10   18
# 24   50
# 12   27
# 3    52
# 7    60
# 23   45
# 14   49
# 19   18
# 26   23
# 11   28
# 22   40
# 4    46

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()

# %%
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model_lr.predict(X_test)
# Out:
# array([0, 1, 0])

# %%
X_test
# Out:
#     age
# 18   19
# 2    47
# 21   26

# %%
model_lr.score(X_test, y_test)
# Out:
# 1.0

# %%
import numpy as np

# %%
X_test = np.linspace(X_train.min(), X_train.max(), 300).reshape(-1, 1)
y_prob = model_lr.predict_proba(X_test)[:,1]
# Out:
# c:\Python3.13\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X_train, y_train, color='black')
plt.plot(X_test, y_prob, color= 'red')
plt.axhline(0.5, color='blue', linestyle='--')
plt.xlabel('Feature')
plt.ylabel('Probability')
plt.title('Your Logistic Regression Model')
plt.show()
